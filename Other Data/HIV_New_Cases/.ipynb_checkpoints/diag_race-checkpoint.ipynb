# %%
#Dependencies
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# If re running files have been moved so double check folder and file names

# %%
diag_files = glob.glob("*.csv")
diag_files
# Out:
# ['Diag_Race_National_CandR.csv',
#  'Diag_Race_County_CandR.csv',
#  'Diag_Race_State_CandR.csv']

# %%
def parsed(x):
    try:
        return int(x)
    except:
        return x
i=0

for f in diag_files:
    diag_race_df = pd.read_csv(f)
    #Shorten and rename columns (for usability) American Indian/Alaska Native=AI_AN, Asian, Black/African American=Black, Hispanic/Latino=Latino, Multiple races=Multi, Native Hawaiian/Other Pacific Islander=NH_OPI, White
    diag_race_df = diag_race_df.rename(columns={'American Indian/Alaska Native 2008':'AI_AN Cases 08','Unnamed: 2':'AI_AN Rate 08','Asian 2008':'Asian Cases 08','Unnamed: 4':'Asian Rate 08','Black/African American 2008':'Black Cases 08','Unnamed: 6':'Black Rate 08','Hispanic/Latino 2008':'Latino Cases 08','Unnamed: 8':'Latino Rate 08','Multiple races 2008':'Multi Cases 08','Unnamed: 10':'Multi Rate 08','Native Hawaiian/Other Pacific Islander 2008':'NH_OPI Cases 08','Unnamed: 12':'NH_OPI Rate 08','White 2008':'White Cases 08','Unnamed: 14':'White Rate 08',
                                                    'American Indian/Alaska Native 2009':'AI_AN Cases 09','Unnamed: 16':'AI_AN Rate 09','Asian 2009':'Asian Cases 09','Unnamed: 18':'Asian Rate 09','Black/African American 2009':'Black Cases 09','Unnamed: 20':'Black Rate 09','Hispanic/Latino 2009':'Latino Cases 09','Unnamed: 22':'Latino Rate 09','Multiple races 2009':'Multi Cases 09','Unnamed: 24':'Multi Rate 09','Native Hawaiian/Other Pacific Islander 2009':'NH_OPI Cases 09','Unnamed: 26':'NH_OPI Rate 09','White 2009':'White Cases 09','Unnamed: 28':'White Rate 09',
                                                    'American Indian/Alaska Native 2010':'AI_AN Cases 10','Unnamed: 30':'AI_AN Rate 10','Asian 2010':'Asian Cases 10','Unnamed: 32':'Asian Rate 10','Black/African American 2010':'Black Cases 10','Unnamed: 34':'Black Rate 10','Hispanic/Latino 2010':'Latino Cases 10','Unnamed: 36':'Latino Rate 10','Multiple races 2010':'Multi Cases 10','Unnamed: 38':'Multi Rate 10','Native Hawaiian/Other Pacific Islander 2010':'NH_OPI Cases 10','Unnamed: 40':'NH_OPI Rate 10','White 2010':'White Cases 10','Unnamed: 42':'White Rate 10',
                                                    'American Indian/Alaska Native 2011':'AI_AN Cases 11','Unnamed: 44':'AI_AN Rate 11','Asian 2011':'Asian Cases 11','Unnamed: 46':'Asian Rate 11','Black/African American 2011':'Black Cases 11','Unnamed: 48':'Black Rate 11','Hispanic/Latino 2011':'Latino Cases 11','Unnamed: 50':'Latino Rate 11','Multiple races 2011':'Multi Cases 11','Unnamed: 52':'Multi Rate 11','Native Hawaiian/Other Pacific Islander 2011':'NH_OPI Cases 11','Unnamed: 54':'NH_OPI Rate 11','White 2011':'White Cases 11','Unnamed: 56':'White Rate 11',
                                                    'American Indian/Alaska Native 2017':'AI_AN Cases 17','Unnamed: 128':'AI_AN Rate 17','Asian 2017':'Asian Cases 17','Unnamed: 130':'Asian Rate 17','Black/African American 2017':'Black Cases 17','Unnamed: 132':'Black Rate 17','Hispanic/Latino 2017':'Latino Cases 17','Unnamed: 134':'Latino Rate 17','Multiple races 2017':'Multi Cases 17','Unnamed: 136':'Multi Rate 17','Native Hawaiian/Other Pacific Islander 2017':'NH_OPI Cases 17','Unnamed: 138':'NH_OPI Rate 17','White 2017':'White Cases 17','Unnamed: 140':'White Rate 17',
                                                    'American Indian/Alaska Native 2018':'AI_AN Cases 18','Unnamed: 142':'AI_AN Rate 18','Asian 2018':'Asian Cases 18','Unnamed: 144':'Asian Rate 18','Black/African American 2018':'Black Cases 18','Unnamed: 146':'Black Rate 18','Hispanic/Latino 2018':'Latino Cases 18','Unnamed: 148':'Latino Rate 18','Multiple races 2018':'Multi Cases 18','Unnamed: 150':'Multi Rate 18','Native Hawaiian/Other Pacific Islander 2018':'NH_OPI Cases 18','Unnamed: 152':'NH_OPI Rate 18','White 2018':'White Cases 18','Unnamed: 154':'White Rate 18'
    })

    diag_race_df = diag_race_df.iloc[1:].replace({'Data suppressed': np.nan, ',': ''}, regex=True)
    diag_race_df = diag_race_df.apply(lambda x: parsed(x))
    if i>1:
        diag_race_df1 = diag_race_df
    elif i>0:
        diag_race_df2 = diag_race_df
    else:
        diag_race_df0 = diag_race_df
    i = i + 1

# print(diag_race_df0.head())
# print(diag_race_df1.head())
# print(diag_race_df2.head())
diag_race_data = pd.concat([diag_race_df0,diag_race_df1,diag_race_df2])
diag_race_data.head()
# Out:
#        Geography AI_AN Cases 08 AI_AN Rate 08 Asian Cases 08 Asian Rate 08  \
# 1  United States            147           7.9            659             6
# 1        Alabama              1           5.1              3           8.1
# 2         Alaska             12          15.1              0             0
# 3        Arizona             27            13             11           8.6
# 4       Arkansas              1           5.9              1             4
#
#   Black Cases 08 Black Rate 08 Latino Cases 08 Latino Rate 08 Multi Cases 08  \
# 1          21719          72.5            9820           28.3           2327
# 1            487          49.4              27           28.7             52
# 2              7            34               1            3.3              1
# 3             63          34.7             237           16.8             15
# 4            122          34.8              18           16.2             14
#
# ...

# %%
diag_race_data
# Out:
#                          Geography AI_AN Cases 08 AI_AN Rate 08  \
# 1                    United States            147           7.9
# 1                          Alabama              1           5.1
# 2                           Alaska             12          15.1
# 3                          Arizona             27            13
# 4                         Arkansas              1           5.9
# 5                       California             15           9.2
# 6                         Colorado              3           9.9
# 7                      Connecticut              0             0
# 8                         Delaware              0             0
# 9             District of Columbia              1          74.4
# 10                         Florida              6          13.2
# 11                         Georgia              0             0
# 12                          Hawaii              0             0
# 13                           Idaho              1           6.7
# ...

# %%
diag_race_data.to_csv('diag_race.csv',index=False)
