# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
import time
import re

# %%
#https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver

#Initiate browser w/ Splinter
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# /usr/local/bin/chromedriver
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-2-77d75c96686d> in <module>
#       4 #Initiate browser w/ Splinter
#       5 executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# ----> 6 browser = Browser('chrome', **executable_path, headless=False)
#
# ~/anaconda3/lib/python3.7/site-packages/splinter/browser.py in Browser(driver_name, *args, **kwargs)
#      62     except KeyError:
#      63         raise DriverNotFoundError("No driver for %s" % driver_name)
# ---> 64     return driver(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/splinter/driver/webdriver/chrome.py in __init__(self, options, user_agent, wait_time, fullscreen, incognito, headless, **kwargs)
#      41             options.add_argument("--disable-gpu")
#      42
# ---> 43         self.driver = Chrome(options=options, **kwargs)
#      44
#      45         self.element_class = WebDriverElement
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 78

# %%
# URL of page to be scraped
url = 'https://www.everydayhealth.com/drugs/truvada/reviews'
#adding in splinter needed item
browser.visit(url)

# %%
#Drug names to keep in lists
all_brand_hiv_drugs = ['Combivir', 'Emtriva', 'Epivir', 'Epizicom','Hivid','Trizivir',
    'Truvada','Videx','Viread','Zerit','Ziagen','Edurant','Intelence',
    'Rescriptor','Pifeltro','Sustiva','Viramune','Agenerase','Aptivus',
    'Crixivan','Invirase','Kaletra','Lexiva','Norvir','Prezista','Reyataz',
    'Viracept','Selzentry','Isentress','Tivicay','Vitekta','Atripla','Biktarvy',
    'Cimduo','Complera','Delstrigo','Dovato','Genvoya','Evotaz','Juluca',
    'Odefsey','Prezcobix','Symfi','Stribild','Symtuza','Triumeq','Descovy']
#Drug classes and abbrv's NRTs:Nucleoside Reverse Transcriptase Inhibitor; NNRTIs: Non-Nucleoside
#Reverse Transcriptase Inhibitor; PIs: Protease Inhibitor; CAs:CCR5 Antagonist; INSTIs: Integrase
# Inhibitor; MCCs: Multi-Class Combination; PrEPs: Pre-Exposure Prophylaxis; PEPs: Post-Exposure Prophylaxis
hiv_drug_classes = ['NRTs','NNRTIs','PIs','CAs','INSTIs','MCCs','PrEPs','PEPs']
nrts = ['Combivir', 'Emtriva', 'Epivir', 'Epizicom','Hivid','Trizivir',
            'Videx','Viread','Zerit','Ziagen'] #'Truvada'
nnrtis = ['Edurant','Intelence','Rescriptor','Pifeltro','Sustiva','Viramune']
pis = ['Agenerase','Aptivus','Crixivan','Invirase','Kaletra','Lexiva','Norvir',
      'Prezista','Reyataz','Viracept']
cas = ['Selzentry']
instis = ['Isentress','Tivicay','Vitekta']
mccs = ['Atripla','Biktarvy','Cimduo','Complera','Delstrigo','Dovato','Genvoya',
       'Evotaz','Juluca','Odefsey','Prezcobix','Symfi','Stribild','Symtuza','Triumeq']
preps = ['Truvada','Descovy']

# %% [markdown]
# Scrape drug information from first website

# %%
html = browser.html
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(html, 'html.parser')
#Retrieve all elements that contain organization information in an iterable list
results = soup.find_all('div', class_='review-container row')
# print(results)

# %%
#Empty lists to hold our scraped information
brands = []
what_fors = []
reviews = []
star_ratings =[]
dates_posted = []

for d in all_brand_hiv_drugs:
    url = f'https://www.everydayhealth.com/drugs/{d}/reviews'
    browser.visit(url)
    html = browser.html
    # Create BeautifulSoup object; parse with 'html.parser' 
    soup = bs(html, 'html.parser')
    
    #Retrieve all elements that contain organization information in an iterable list
    if (soup.body.find(class_="error-404")):
        print(f'{d}: Drug Not Found')
    
    elif (soup.body.find(class_="no-reviews")):
        print(f'{d}: No Reviews')
    
    else:
        results = soup.body.find_all(class_='review-container row')
#       print(results)

        for r in results:
            #Scrape our info
            brand = r.h3.span.text    #scrapes the name of the drug (brand name only at the moment)
            what = r.h3.text     #scrapes the reason why taking still need to strip other info
            review = r.p.text    #scrapes the review
            rating = r.find('div', class_='star-rating-print').text # Gives stars-rating with "Stars" after if want without "Stars" use .strip("Stars") after
            date = r.find('span', class_='time')['content']   #scrapes date and time posted (can split if needed)
    
    
            #Append scraped info to their respective lists
            brands.append(brand)
            what_fors.append(what)
            reviews.append(review)
            star_ratings.append(rating)
            dates_posted.append(date)
    
print(brands, what_fors, reviews, star_ratings,dates_posted)
# Out:
# ['Truvada', 'Truvada', 'Truvada'] ['Rated Truvada for Human Immunodeficiency Virus (HIV) Prophylaxis Report ', 'Rated Truvada for HIV Report ', 'Rated Truvada for HIV Infection Report '] ['The once a day therapy of Atripla caused side effects such as dizziness, and a sort of "foggy" feeling into the following day there were days that my fingertips felt numb as well. These symptoms are said to be normal especially in the first few months of use. My symptoms continued for two years, so I asked my doctor to consider an alternate therapy. The new therapy recommended was once a day Truvada and twice a day Intelence. Since then I have experienced no side effects. So far (4 years) I am happy with this choice.', 'A little insomnia at the beginning and a generalized tired feeling for a couple of weeks, but after that, no problems. It was a helluva lot better than Atripla.', 'it really dose help if you can stand the side effects of it'] ['4.5 Stars', '4 Stars', '2.5 Stars'] ['11/19/2013 10:44:05 PM', '1/3/2013 12:43:00 AM', '4/4/2008 7:47:15 AM']

# %%
drug_review_df = pd.DataFrame({'Name':brands,'Reason':what_fors,'Reviews':reviews,
                               'Date Posted':dates_posted,'Ratings':star_ratings})
drug_review_df
# Out:
#       Name                                             Reason  \
# 0  Truvada  Rated Truvada for Human Immunodeficiency Virus...
# 1  Truvada                      Rated Truvada for HIV Report
# 2  Truvada            Rated Truvada for HIV Infection Report
#
#                                              Reviews             Date Posted  \
# 0  The once a day therapy of Atripla caused side ...  11/19/2013 10:44:05 PM
# 1  A little insomnia at the beginning and a gener...    1/3/2013 12:43:00 AM
# 2  it really dose help if you can stand the side ...     4/4/2008 7:47:15 AM
#
#      Ratings
# 0  4.5 Stars
# 1    4 Stars
# 2  2.5 Stars

# %%
#Strip down reason for taking to HIV treatment and PrEP
reason_df = drug_review_df

reason_df.loc[reason_df['Reason'].str.contains('Prophylaxis|PrEP|PREP|prep'), 'Reason']= 'PrEP'
reason_df.loc[reason_df['Reason'].str.contains('HIV'), 'Reason'] = 'HIV treatment'


reason_df
# Out:
#       Name         Reason                                            Reviews  \
# 0  Truvada           PrEP  The once a day therapy of Atripla caused side ...
# 1  Truvada  HIV treatment  A little insomnia at the beginning and a gener...
# 2  Truvada  HIV treatment  it really dose help if you can stand the side ...
#
#               Date Posted    Ratings Classify
# 0  11/19/2013 10:44:05 PM  4.5 Stars     PrEP
# 1    1/3/2013 12:43:00 AM    4 Stars     PrEP
# 2     4/4/2008 7:47:15 AM  2.5 Stars     PrEP

# %%
#Classify drugs
#Truvada and Descovy will need a secondary statement based on why they are being taken
# df.loc[df['Name'] == 'Truvada|Descovy', 'Classify']='PrEP'

# df.loc[df['Name'].isin(preps), 'Classify']='PrEP'
# df.loc[df['Name'].isin(mccs), 'Classify']='MMC'
# df.loc[df['Name'].isin(instis), 'Classify']='INSTI'
# df.loc[df['Name'].isin(nnrtis), 'Classify']='NNRTI'
# df.loc[df['Name'].isin(nrts), 'Classify']='NRT'
# df.loc[df['Name'].isin(pis), 'Classify']='PI'
classified_df = reason_df
classified_df['Classify'] = pd.np.where(classified_df.Name.isin(preps), 'PrEP',
                    pd.np.where(classified_df.Name.isin(mccs), 'MMC',
                    pd.np.where(classified_df.Name.isin(instis), 'INSTI',
                    pd.np.where(classified_df.Name.isin(nnrtis), 'NNRTI',
                    pd.np.where(classified_df.Name.isin(nrts), 'NRT',
                    pd.np.where(classified_df.Name.isin(pis), 'PI', 'None'            
                    ))))))
classified_df
# Out:
#       Name         Reason                                            Reviews  \
# 0  Truvada           PrEP  The once a day therapy of Atripla caused side ...
# 1  Truvada  HIV treatment  A little insomnia at the beginning and a gener...
# 2  Truvada  HIV treatment  it really dose help if you can stand the side ...
#
#               Date Posted    Ratings Classify
# 0  11/19/2013 10:44:05 PM  4.5 Stars     PrEP
# 1    1/3/2013 12:43:00 AM    4 Stars     PrEP
# 2     4/4/2008 7:47:15 AM  2.5 Stars     PrEP

# %%
# Out:
#       Name         Reason                                            Reviews  \
# 0  Truvada           PrEP  The once a day therapy of Atripla caused side ...
# 1  Truvada  HIV treatment  A little insomnia at the beginning and a gener...
# 2  Truvada  HIV treatment  it really dose help if you can stand the side ...
#
#               Date Posted    Ratings Classify
# 0  11/19/2013 10:44:05 PM  4.5 Stars     PrEP
# 1    1/3/2013 12:43:00 AM    4 Stars     PrEP
# 2     4/4/2008 7:47:15 AM  2.5 Stars     PrEP
