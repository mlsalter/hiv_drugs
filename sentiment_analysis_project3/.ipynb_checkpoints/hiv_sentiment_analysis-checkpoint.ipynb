# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\johar\anaconda3\lib\site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in c:\users\johar\anaconda3\lib\site-packages (from textblob) (3.4.4)
# Requirement already satisfied: six in c:\users\johar\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.12.0)

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\johar\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\johar\anaconda3\lib\site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in c:\users\johar\anaconda3\lib\site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\johar\anaconda3\lib\site-packages (from tweepy) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\johar\anaconda3\lib\site-packages (from tweepy) (1.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\johar\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\johar\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\johar\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\johar\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.24.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\johar\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)

# %%
import tweepy
from textblob import TextBlob
import pandas as pd

# %%
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
public_tweets = api.search('hiv prevention')

# %%
print(TextBlob(public_tweets[0].text).sentiment)
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
subjectivityList = []
polarityList = []
tweetsList = []

for i in range(len(public_tweets)):
    tweetsList.append(public_tweets[i].text)
    
    sentiment=TextBlob(public_tweets[i].text).sentiment
    subjectivity= sentiment.subjectivity
    subjectivityList.append(subjectivity)
    
    polarity = sentiment.polarity
    polarityList.append(polarity)

# %%
tweetsList
# Out:
# ["RT @AMychkovsky: If you follow #coronavirus, you must know Dr. Debbie Birx. Birx directed the CDC &amp; Prevention's global HIV/AIDS division.…",
#  "RT @angryblkhoemo: Most any sexually active person already knows what condoms are and why they're useful\n\n...yet some folks are still not g…",
#  'RT @angryblkhoemo: ...or...advocating for the various methods of viable HIV/AIDS prevention and treatment that include the reality that som…',
#  '@caseyhouseTO Absolutely and I did so in the 80s when my dad revealed he was had AIDS. After his death in 1991, I v… https://t.co/GHU7ZUaNC1',
#  'RT @angryblkhoemo: ...or...advocating for the various methods of viable HIV/AIDS prevention and treatment that include the reality that som…',
#  "RT @AMychkovsky: If you follow #coronavirus, you must know Dr. Debbie Birx. Birx directed the CDC &amp; Prevention's global HIV/AIDS division.…",
#  'From anti-transgender violence to HIV and AIDS prevention, treatment and research, the 2020 Democratic presidential… https://t.co/RnieVgq5yy',
#  'RT @JayGordonMDFAAP: Sitting in an airport watching Mike Pence speak about coronavirus. Can’t hear him nor read the closed captions.  I fee…',
#  'People at higher risk should get tested more often. You should get an HIV test as soon as possible if:\nYou were HIV… https://t.co/mwZd3SeNj9',
#  'RT @ETAForg: #ICYMI Our Ambassador \u2066@kathyireland\u2069 accepted $1,000,000 on behalf of ETAF last Thursday! These funds will support youth HIV…',
#  'Misleading ads turn people away from HIV-prevention meds https://t.co/uZf44ExOOM',
#  '#ICYMI Our Ambassador \u2066@kathyireland\u2069 accepted $1,000,000 on behalf of ETAF last Thursday! These funds will support… https://t.co/SeINYwzgU0',
#  'RT @angryblkhoemo: ...or...advocating for the various methods of viable HIV/AIDS prevention and treatment that include the reality that som…',
#  'RT @IPMicrobicides: Yes! And one where women have a range of #HIV prevention options so they can choose what works best from them. \n\n#SheDe…',
#  'From anti-transgender violence to HIV and AIDS prevention, treatment and research, the 2020 Democratic presidential… https://t.co/0kEXzX9qqD']

# %%
subjectivityList
# Out:
# [0.0,
#  0.3666666666666667,
#  0.5,
#  0.9,
#  0.5,
#  0.0,
#  0.0,
#  0.1,
#  0.6666666666666666,
#  0.06666666666666667,
#  0.0,
#  0.06666666666666667,
#  0.5,
#  0.3,
#  0.0]

# %%
sentimentDict = {
            "polarity": polarityList,
             "subjectivity": subjectivityList, 
             "tweets": tweetsList
            }

# %%
sentiment_df = pd.DataFrame(sentimentDict)
sentiment_df
# Out:
#     polarity  subjectivity                                             tweets
# 0   0.000000      0.000000  RT @AMychkovsky: If you follow #coronavirus, y...
# 1   0.222222      0.366667  RT @angryblkhoemo: Most any sexually active pe...
# 2   0.000000      0.500000  RT @angryblkhoemo: ...or...advocating for the ...
# 3   0.200000      0.900000  @caseyhouseTO Absolutely and I did so in the 8...
# 4   0.000000      0.500000  RT @angryblkhoemo: ...or...advocating for the ...
# 5   0.000000      0.000000  RT @AMychkovsky: If you follow #coronavirus, y...
# 6   0.000000      0.000000  From anti-transgender violence to HIV and AIDS...
# 7  -0.100000      0.100000  RT @JayGordonMDFAAP: Sitting in an airport wat...
# 8   0.250000      0.666667  People at higher risk should get tested more o...
# 9   0.000000      0.066667  RT @ETAForg: #ICYMI Our Ambassador ⁦@kathyirel...
# 10  0.000000      0.000000  Misleading ads turn people away from HIV-preve...
# 11  0.000000      0.066667  #ICYMI Our Ambassador ⁦@kathyireland⁩ accepted...
# 12  0.000000      0.500000  RT @angryblkhoemo: ...or...advocating for the ...
# 13  1.000000      0.300000  RT @IPMicrobicides: Yes! And one where women h...
# 14  0.000000      0.000000  From anti-transgender violence to HIV and AIDS...

# %%
 for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
# Out:
# RT @AMychkovsky: If you follow #coronavirus, you must know Dr. Debbie Birx. Birx directed the CDC &amp; Prevention's global HIV/AIDS division.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @angryblkhoemo: Most any sexually active person already knows what condoms are and why they're useful
#
# ...yet some folks are still not g…
# Sentiment(polarity=0.22222222222222224, subjectivity=0.3666666666666667)
# RT @angryblkhoemo: ...or...advocating for the various methods of viable HIV/AIDS prevention and treatment that include the reality that som…
# Sentiment(polarity=0.0, subjectivity=0.5)
# @caseyhouseTO Absolutely and I did so in the 80s when my dad revealed he was had AIDS. After his death in 1991, I v… https://t.co/GHU7ZUaNC1
# Sentiment(polarity=0.2, subjectivity=0.9)
# RT @angryblkhoemo: ...or...advocating for the various methods of viable HIV/AIDS prevention and treatment that include the reality that som…
# Sentiment(polarity=0.0, subjectivity=0.5)
# RT @AMychkovsky: If you follow #coronavirus, you must know Dr. Debbie Birx. Birx directed the CDC &amp; Prevention's global HIV/AIDS division.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# From anti-transgender violence to HIV and AIDS prevention, treatment and research, the 2020 Democratic presidential… https://t.co/RnieVgq5yy
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @JayGordonMDFAAP: Sitting in an airport watching Mike Pence speak about coronavirus. Can’t hear him nor read the closed captions.  I fee…
# Sentiment(polarity=-0.1, subjectivity=0.1)
# People at higher risk should get tested more often. You should get an HIV test as soon as possible if:
# You were HIV… https://t.co/mwZd3SeNj9
# Sentiment(polarity=0.25, subjectivity=0.6666666666666666)
# RT @ETAForg: #ICYMI Our Ambassador ⁦@kathyireland⁩ accepted $1,000,000 on behalf of ETAF last Thursday! These funds will support youth HIV…
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Misleading ads turn people away from HIV-prevention meds https://t.co/uZf44ExOOM
# Sentiment(polarity=0.0, subjectivity=0.0)
# #ICYMI Our Ambassador ⁦@kathyireland⁩ accepted $1,000,000 on behalf of ETAF last Thursday! These funds will support… https://t.co/SeINYwzgU0
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# RT @angryblkhoemo: ...or...advocating for the various methods of viable HIV/AIDS prevention and treatment that include the reality that som…
# Sentiment(polarity=0.0, subjectivity=0.5)
# RT @IPMicrobicides: Yes! And one where women have a range of #HIV prevention options so they can choose what works best from them.
#
# #SheDe…
# Sentiment(polarity=1.0, subjectivity=0.3)
# From anti-transgender violence to HIV and AIDS prevention, treatment and research, the 2020 Democratic presidential… https://t.co/0kEXzX9qqD
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.figure(figsize=(10,5))
plt.scatter(sentiment_df.polarity, sentiment_df.subjectivity, c=sentiment_df.polarity, s=100, cmap='RdYlGn')
plt.xlabel('Tweet polarity')
plt.ylabel('Tweet subjectivity')
plt.xlim(-1.1, 1.1)
plt.ylim(-0.1, 1.1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
