# %%
#Dependencies
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
case_files = glob.glob("Resources/*.csv")
case_files
# Out:
# ['Resources/Diag_Race_National_CandR.csv',
#  'Resources/Diag_Race_County_CandR.csv',
#  'Resources/Diag_Race_State_CandR.csv']

# %%
#read in csv's to use
diag_race_nat_cr = pd.read_csv('Resources/Diag_Race_National_CandR.csv')
diag_race_st_cr = pd.read_csv('Resources/Diag_Race_State_CandR.csv')
diag_race_cnty_cr = pd.read_csv('Resources/Diag_Race_County_CandR.csv')
#'Raw' data
# diag_nat = pd.read_csv('Resources/Raw/Diag_Race_National.csv')
# diag_st_ = pd.read_csv('Resources/Raw/Diag_Race_State.csv')
# diag_cnty_ = pd.read_csv('Resources/Raw/Diag_Race_County.csv')
diag_race_nat_cr['Geography'] = 'US'
diag_race_nat_cr
# Out:
#                             2008       Unnamed: 1 Unnamed: 2       Unnamed: 3  \
# 0  American Indian/Alaska Native              NaN      Asian              NaN
# 1                          Cases  Rate per 100000      Cases  Rate per 100000
# 2                            147              7.9        659                6
#
#                Unnamed: 4       Unnamed: 5       Unnamed: 6       Unnamed: 7  \
# 0  Black/African American              NaN  Hispanic/Latino              NaN
# 1                   Cases  Rate per 100000            Cases  Rate per 100000
# 2                  21,719             72.5            9,820             28.3
#
#        Unnamed: 8       Unnamed: 9  ...     Unnamed: 145     Unnamed: 146  \
# 0  Multiple races              NaN  ...              NaN  Hispanic/Latino
# 1           Cases  Rate per 100000  ...  Rate per 100000            Cases
# 2           2,327             82.1  ...             47.5            9,664
#
# ...
